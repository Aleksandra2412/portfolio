# %%
#Уровень 0:
#Задание 1
#Посчитайте частные производные функций:
import sympy as sym
x = sym.Symbol('x')
y = sym.Symbol('y')

2 * x**2 * y**3 + 1/x + y**2 * x + 7
# Out:
# 2*x**2*y**3 + x*y**2 + 7 + 1/x

# %%
m = sym.diff(2*x**2*y**3 + 1/x + y**2*x + 7, x ) #по Х
m
# Out:
# 4*x*y**3 + y**2 - 1/x**2

# %%
n= sym.diff(2*x**2*y**3 + 1/x + y**2*x + 7, y)#по У
n
# Out:
# 6*x**2*y**2 + 2*x*y

# %%
 sym.diff(2*x**2*y**3 + 1/x + y**2*x + 7, x, y)#смешанная
# Out:
# 2*y*(6*x*y + 1)

# %%
import math

x = sym.Symbol('x')
y = sym.Symbol('y')
s = x**2 * y - sym.sin((x * y)) + sym.cos((x**2)) + 6 * y
sym.diff(s,x)
# Out:
# 2*x*y - 2*x*sin(x**2) - y*cos(x*y)

# %%
sym.diff(s, y)
# Out:
# x**2 - x*cos(x*y) + 6

# %%
sym.diff(s, x, y)
# Out:
# x*y*sin(x*y) + 2*x - cos(x*y)

# %%
import numpy as np # градиент первой функции в точке (1, 2)
grad = np.array([m.subs(x, 1).subs(y, 2) ,n.subs(x, 1).subs(y, 2)])

# %%
grad
# Out:
# array([35, 28], dtype=object)

# %%
#Задание 3
#Постройте трехмерный график функции
x1 = sym.Symbol('x1')
x2 = sym.Symbol('x2')
def f(x1, x2):
    return x2**2 - x1**2 * x2 + 2 * x1 * x2

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator

fig = plt.figure(figsize=(15,9))
ax = fig.gca(projection='3d')

X = np.arange(-10, 10, 1)
Y = np.arange(-10, 10, 1)
X, Y = np.meshgrid(X, Y)
Z = f(X, Y)
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)
plt.show()
# Out:
# /var/folders/lc/1rfqrt1j091ccy6l5rbbnx0h0000gn/T/ipykernel_4040/2200746381.py:6: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
