# %%
## Задание 1
import sympy as sym
from sympy import *
import numpy as np
x = sym.Symbol ('x')

# %%
#Вычислите производную функции: tg**2(sin(x) + cos(2*x + 3)) 

#в точке x0 = 1

# %%
f = sym.tan(sym.sin(x) + sym.cos(2*x + 3))**2
f
# Out:
# tan(sin(x) + cos(2*x + 3))**2

# %%
f1 = diff(f).evalf(subs={ x: 1})
f1
# Out:
# 55.3859176353379

# %%
#Задание 2
#Дан объект в  2D пространстве
import numpy as np
import matplotlib.pyplot as plt

A = [
[-100, -100, 1],
[0, 100, 1],
[100, -100, 1],
[-100, -100, 1]
]

A = np.array(A)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
A
# Out:
# array([[-100, -100,    1],
#        [   0,  100,    1],
#        [ 100, -100,    1],
#        [-100, -100,    1]])

# %%
#При помощи матричных операций выполните:

#Масштабирование и смещение объекта (применить 2 матрицы трансформаций). 
#Масштабирование на (0.5, 1.2) и смещение на (200, 300)

# %%
B = np.dot(A, 0.5)
x = B[:,0]
y = B[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
C = np.dot(A, 1.2)
x = C[:,0]
y = C[:,1]
plt.plot(x, y)
plt.ylim([-200, 200])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
A = [     #смещение на 200 вдоль оси X
[100, -100, 1],
[200, 100, 1],
[300, -100, 1],
[100, -100, 1]
]

A = np.array(A)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([- 200, 200])
plt.xlim([0, 400])
# Out:
# (0.0, 400.0)

# %%
A = [    # смещение на 300 по оси y
[-100, 200, 1],
[0, 400, 1],
[100, 200, 1],
[-100, 200, 1]
]

A = np.array(A)

x = A[:,0]
y = A[:,1]
plt.plot(x, y)
plt.ylim([0, 400])
plt.xlim([-200, 200])
# Out:
# (-200.0, 200.0)

# %%
#Задание 3
#Найдите собственные значения и собственные вектора матрицы:
m = np.array([[1, 4],
              [1, 1]])
print(m)
# Out:
# [[1 4]
#  [1 1]]

# %%
np.linalg.eig(m)
# Out:
# (array([ 3., -1.]),
#  array([[ 0.89442719, -0.89442719],
#         [ 0.4472136 ,  0.4472136 ]]))

# %%
def f(x, a, b):
    return np.e**a * np.sin(b*x) + x

# %%
x = np.array([0.        , 0.26315789, 0.52631579, 0.78947368, 1.05263158,
              1.31578947, 1.57894737, 1.84210526, 2.10526316, 2.36842105,
              2.63157895, 2.89473684, 3.15789474, 3.42105263, 3.68421053,
              3.94736842, 4.21052632, 4.47368421, 4.73684211, 5.        ])

fx = np.array([  0.        , -12.01819092, -18.90968634, -17.68786571,
                -8.7529108 ,   4.27524517,  16.06801336,  21.81250213,
                19.22059845,   9.48411207,  -3.22273056, -13.48576488,
               -16.91096359, -11.95866834,  -0.58630088,  12.56873816,
                22.12489421,  24.20292139,  18.04522521,   6.33211092])

# %%
plt.plot(x, fx)
plt.show()

# %%
def error(params):
    return np.sum(np.abs(fx - f(x, params[0], params[1])))

# %%
import scipy
import pandas as pd

# %matplotlib inline
from scipy.optimize import minimize

res = minimize(error, [0,0], method='COBYLA')
np.around(res.x,2)
# Out:
# array([ 3. , -2.5])

# %%
fig = plt.figure(figsize=(10, 5), dpi=80)
ax = fig.add_subplot(111)
x_plot = np.linspace(0, 5, 100)
ax_1 = ax.plot(
    x_plot, f(x_plot, *res.x),
    color='red',
    label='оптимизированные значения')
ax_2 = ax.plot(
    x, fx,
    marker='D',
    color='blue',
    label='Начальные данные')
xl = ax.set_xlabel('x')
yl = ax.set_ylabel('f(x)')
l = ax.legend()
t = plt.title('Результат минимизации ошибок')

# %%
#Задание 5
#Дана матрица рейтингов фильмов (строки - пользователи (10 человек), столбцы - фильмы (15 фильмов))

raitings = np.array([[ 4,  4,  9,  4,  1,  6, 10,  7,  9,  6,  9,  2,  8,  6,  6],
                     [ 9,  2,  5, 10,  7,  8, 10,  5,  6,  2,  1,  6,  8,  9,  7],
                     [ 1,  6,  8,  8,  4,  9,  3,  8, 10,  5,  2,  6,  8,  1,  6],
                     [ 6,  1,  9,  7,  7,  9,  2,  3,  5,  1,  6,  6,  3,  2,  7],
                     [ 3,  7,  3,  5,  7,  9,  9,  6,  2,  9,  1,  2,  8, 10,  6],
                     [ 8,  3,  7,  3,  8,  6,  1,  8,  8,  6,  1,  9,  4, 10,  1],
                     [ 9,  8,  4,  8,  8, 10,  6,  1,  1,  2,  9,  5,  2,  7,  2],
                     [ 4,  1,  6,  4,  3, 10,  4,  4,  2,  8,  7,  9,  3,  8,  3],
                     [ 2,  7,  7,  6, 10,  6,  8,  9,  8,  6, 10,  1,  7, 10,  4],
                     [ 5, 10,  8,  8,  9,  7,  2,  9,  9, 10,  8,  8,  8,  6, 10]])

# %%
#Необходимо найти наиболее похожего пользователя по косинусной метрике 
#для каждого из пользователей 
#(ответ: 10 пар вида (x, y), где y - наиболее похожий пользователь на пользователя x).

# %%
def similar(a,b): #через косинусное сходство
  return np.dot(a,b)/(np.linalg.norm(a)*np.linalg.norm(b))
a,b = 0,0

for i in range(len(raitings)):
  for j in range(len(raitings)):
    if i != j:
       similar(raitings[i],raitings[j]) < res
       res = similar(raitings[i],raitings[j])
       a,b = raitings[i],raitings[j]
  print(a,b)
# Out:
# [ 4  4  9  4  1  6 10  7  9  6  9  2  8  6  6] [ 5 10  8  8  9  7  2  9  9 10  8  8  8  6 10]
# [ 9  2  5 10  7  8 10  5  6  2  1  6  8  9  7] [ 5 10  8  8  9  7  2  9  9 10  8  8  8  6 10]
# [ 1  6  8  8  4  9  3  8 10  5  2  6  8  1  6] [ 5 10  8  8  9  7  2  9  9 10  8  8  8  6 10]
# [6 1 9 7 7 9 2 3 5 1 6 6 3 2 7] [ 5 10  8  8  9  7  2  9  9 10  8  8  8  6 10]
# [ 3  7  3  5  7  9  9  6  2  9  1  2  8 10  6] [ 5 10  8  8  9  7  2  9  9 10  8  8  8  6 10]
# [ 8  3  7  3  8  6  1  8  8  6  1  9  4 10  1] [ 5 10  8  8  9  7  2  9  9 10  8  8  8  6 10]
# [ 9  8  4  8  8 10  6  1  1  2  9  5  2  7  2] [ 5 10  8  8  9  7  2  9  9 10  8  8  8  6 10]
# [ 4  1  6  4  3 10  4  4  2  8  7  9  3  8  3] [ 5 10  8  8  9  7  2  9  9 10  8  8  8  6 10]
# [ 2  7  7  6 10  6  8  9  8  6 10  1  7 10  4] [ 5 10  8  8  9  7  2  9  9 10  8  8  8  6 10]
# [ 5 10  8  8  9  7  2  9  9 10  8  8  8  6 10] [ 2  7  7  6 10  6  8  9  8  6 10  1  7 10  4]

# %%
from sklearn.metrics import pairwise_distances  #через pairwise_distances

for i, row in enumerate(pairwise_distances(raitings)):
    print(i, list(row).index(np.min(row[np.nonzero(row)])))
# Out:
# 0 8
# 1 4
# 2 9
# 3 7
# 4 1
# 5 7
# 6 3
# 7 3
# 8 0
# 9 2
